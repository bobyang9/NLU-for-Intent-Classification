# %%
import re

# %%
intent = ""
lines = []
with open("atis_intents_train.csv") as file:
    for line in file:
        if(len(line) == 0):
            continue
        lines.append(re.sub(", ", "\t", line))

# %%
print(lines)
# Out:
# ['atis_flight\ti want to fly from boston at 838 am and arrive in denver at 1110 in the morning\n', 'atis_flight\twhat flights are available from pittsburgh to baltimore on thursday morning\n', 'atis_flight_time\twhat is the arrival time in san francisco for the 755 am flight leaving washington\n', 'atis_airfare\tcheapest airfare from tacoma to orlando\n', 'atis_airfare\tround trip fares from pittsburgh to philadelphia under 1000 dollars\n', 'atis_flight\ti need a flight tomorrow from columbus to minneapolis\n', 'atis_aircraft\twhat kind of aircraft is used on a flight from cleveland to dallas\n', 'atis_flight\tshow me the flights from pittsburgh to los angeles on thursday\n', 'atis_flight\tall flights from boston to washington\n', 'atis_ground_service\twhat kind of ground transportation is available in denver\n', 'atis_flight\tshow me the flights from dallas to san francisco\n', 'atis_flight\tshow me the flights from san diego to newark by way of houston\n', 'atis_flight\twhat is the
# ...

# %%
file1 = open("atis_train_actual.csv","w")

file1.writelines(lines)

file1.close()

# %%
intent = ""
lines = []
with open("atis_intents_test.csv") as file:
    for line in file:
        if(len(line) == 0):
            continue
        lines.append(re.sub(", ", "\t", line))

# %%
print(lines)
# Out:
# ['atis_flight\ti would like to find a flight from charlotte to las vegas that makes a stop in st. louis\n', 'atis_airfare\ton april first i need a ticket from tacoma to san jose departing before 7 am\n', 'atis_flight\ton april first i need a flight going from phoenix to san diego\n', 'atis_flight\ti would like a flight traveling one way from phoenix to san diego on april first\n', 'atis_flight\ti would like a flight from orlando to salt lake city for april first on delta airlines\n', 'atis_flight\ti need a flight from toronto to newark one way leaving wednesday evening or thursday morning\n', 'atis_flight\tmonday morning i would like to fly from columbus to indianapolis\n', 'atis_flight\ton wednesday april sixth i would like to fly from long beach to columbus after 3 pm\n', 'atis_flight\tafter 12 pm on wednesday april sixth i would like to fly from long beach to columbus\n', 'atis_flight\tare there any flights from long beach to columbus on wednesday april sixth\n', 'atis_flight\tfin
# ...

# %%
file1 = open("atis_test_actual.csv","w")

file1.writelines(lines)

file1.close()
